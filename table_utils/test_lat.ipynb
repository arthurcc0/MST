# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Users\UFPB\gabriel ayres\MST\table_utils\comparison_dummy_ehr.csv")

# %%
df['Narrative'][0:11]
# Out:
# 0     BREAST MRI INDICATION: Staging evaluation of n...
# 1     BREAST MRI INDICATION: High risk screening.  H...
# 2     BREAST MRI INDICATION: High risk screening.  H...
# 3     BREAST MRI INDICATION: High risk screening.  H...
# 4     BREAST MRI INDICATION: High risk screening.  H...
# 5     BREAST MRI INDICATION: Diagnostic evaluation o...
# 6     BREAST MRI INDICATION: High risk screening.  H...
# 7     BREAST MRI INDICATION: High risk screening.  H...
# 8     BREAST MRI INDICATION: High risk screening.  H...
# 9     BREAST MRI INDICATION: High risk screening.  H...
# 10    BREAST MRI INDICATION: High risk screening.  H...
# Name: Narrative, dtype: object

# %%
# Out:
# 'BREAST MRI INDICATION: Staging evaluation of new breast cancer.  HISTORY: Recently diagnosed left breast moderately differentiated invasive ductal  carcinoma with positive left axillary nodal metastasis.  Ultrasound guided  core biopsy of the left breast was performed 10/23/15.  Core biopsy of the  a left axillary lymph node was also performed.  COMPARISON: Comparison has been made to previous images.  TECHNIQUE: MR BREAST W AND WO IV CONTRAST BILATERAL was performed on a 1.5 tesla  magnet utilizing axial T1, axial T2 weighted images, axial fat suppressed  gradient echo T1 weighted pulse sequences were obtained. Pre-gadolinium,  arterial, and interstitial phases of enhancement were obtained  sequentially. Delayed sagittal T1 weighted images were obtained.  Subtraction images were generated by post processing.  Contrast administered: gadobenate dimeglumine (MULTIHANCE) 529 MG/ML  injection 9 mL, Total Given: 9 mL (1 dose) intravenously without  significant complications.  FINDINGS: T
# ...

# %%
df['laterality'][0]
# Out:
# 2.0

# %%
df['Narrative'][1]
# Out:
# 'BREAST MRI INDICATION: High risk screening.  HISTORY: Prior radiation treatment for lymphoma.  COMPARISON: Comparison has been made to previous images.  TECHNIQUE: MR BREAST W AND WO IV CONTRAST BILATERAL was performed on a 1.5 tesla  magnet utilizing axial T1, axial T2 weighted images, axial fat suppressed  gradient echo T1 weighted pulse sequences were obtained. Pre-gadolinium,  arterial, and interstitial phases of enhancement were obtained  sequentially. Delayed sagittal T1 weighted images were obtained.  Subtraction images were generated by post processing.  Contrast administered: gadobenate dimeglumine (MULTIHANCE) 529 MG/ML  injection 9 mL, Total Given: 9 mL (1 dose) intravenously without  significant complications.  FINDINGS: The breast has scattered fibroglandular tissue. The background parenchymal enhancement is mild. Bilateral There is no suspicious enhancement. Right breast artifact consistent with  prior core biopsy.'

# %%
df['laterality'][1]
# Out:
# 1.0

# %%
df.tail()
# Out:
#                                               Narrative  laterality
# 5311  BREAST MRI INDICATION: High risk screening.  H...         NaN
# 5312  BREAST MRI INDICATION: Evaluation of implant i...         NaN
# 5313  BREAST MRI INDICATION: High risk screening.  H...         NaN
# 5314  HISTORY: Dense breasts. Family history of brea...         NaN
# 5315  HISTORY: High risk evaluation. Prior history o...         NaN
